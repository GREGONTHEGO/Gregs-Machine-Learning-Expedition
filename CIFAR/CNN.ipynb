# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# Define the CNN architecture
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10, num_filters=16, kernel_size=3, padding=1):
        """
        Initializes the CNN.
        Parameters:
            num_classes (int): Number of output classes.
            num_filters (int): Number of filters in the first convolutional layer. 
                The second layer will have 2x this number.
            kernel_size (int): Size of the convolving kernel.
            padding (int): Zero-padding added to both sides of the input.
        """
        self.kernel_size = kernel_size
        self.padding = padding
        self.num_filters = num_filters
        self.input_size = 32
        self.flattened_size = self._get_flattened_size()
        print(num_filters,kernel_size,padding)
        super(SimpleCNN, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, num_filters, kernel_size, stride=1, padding = padding),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(num_filters, 2*num_filters, kernel_size, stride=1, padding = padding),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout(0.5)
        self.fc1 = nn.Linear(self.flattened_size, 1000)
        self.fc2 = nn.Linear(1000, 10)
        

    def _get_flattened_size(self):
        """
        Dynamically calculate the size of the flattened tensor after passing through 
        convolutional and pooling layers based on the kernel size, padding, and input size.
        """
        # After first convolutional layer and pooling
        size_after_layer1 = (self.input_size + 2 * self.padding - self.kernel_size) // 1 + 1
        size_after_layer1 = size_after_layer1 // 2

        size_after_layer2 = (size_after_layer1 + 2 * self.padding - self.kernel_size) // 1 + 1
        size_after_layer2 = size_after_layer2 // 2
        return 2 * self.num_filters * size_after_layer2 * size_after_layer2
    
    def forward(self, x):
        """
        Performs forward pass of the input.
        Parameters:
            x (Tensor): Input tensor.
        Returns:
            out (Tensor): Output tensor.
        """
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out
        pass


# Define transformations for the train set
train_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Define transformations for the validation set
val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Load datasets
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transforms)
val_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=val_transforms)

# Define data loaders
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def train(model, train_loader, lr=0.01, momentum=0.9):
    # Define the loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    
    model.train()  # Set the model to training mode
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

def validate(model, val_loader):
    model.eval()  # Set the model to evaluation mode
    total = 0
    correct = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    print('Validation accuracy: {:.2f}%'.format((accuracy) * 100))
    return accuracy

def visulization(accuracies):
    plt.figure(figsize=(10, 5))
    plt.plot(accuracies)
    plt.title('Validation accuracy over epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()
    
def task1(num_filters=16):
    print('Task 1 with different number of filters')
    num_filters_list = [16, 32, 64, 128] # todo: try different number of filters
    for num_filters in num_filters_list:
        model = SimpleCNN(num_filters=num_filters) 
        model = model.to(device)
        accuracies = []
        for epoch in range(10):  # Loop over the dataset multiple times
            print('Epoch {}/{}'.format(epoch+1, 10))
            train(model, train_loader)
            accuracy = validate(model, val_loader)
            accuracies.append(accuracy)
        visulization(accuracies) # You can use this function to visulize the trend of accuracy change
        
        
def task2():
    print('Task 2 with different kernel sizes')
    kernel_sizes = [3,5,7,9] # todo: try different kernel sizes
    for kernel_size in kernel_sizes:
        model = SimpleCNN(kernel_size=kernel_size) 
        model = model.to(device)
        accuracies = []
        for epoch in range(10):  # Loop over the dataset multiple times
            print('Epoch {}/{}'.format(epoch+1, 10))
            train(model, train_loader)
            accuracy = validate(model, val_loader)
            accuracies.append(accuracy)
        visulization(accuracies) # You can use this function to visulize the trend of accuracy change
        
def task3():
    print('Task 3 with different padding')
    padding_list = [0,1,2,3] # todo: try different padding
    for padding in padding_list:
        model = SimpleCNN(padding=padding) 
        model = model.to(device)
        accuracies = []
        for epoch in range(10):  # Loop over the dataset multiple times
            print('Epoch {}/{}'.format(epoch+1, 10))
            train(model, train_loader)
            accuracy = validate(model, val_loader)
            accuracies.append(accuracy)
        visulization(accuracies) # You can use this function to visulize the trend of accuracy change

if __name__ == "__main__":
    task1()
    task2()
    task3()
# Out:
# Task 1 with different number of filters
# 16 3 1
# Epoch 1/10
# Validation accuracy: 44.85%
# Epoch 2/10
# Validation accuracy: 51.94%
# Epoch 3/10
# Validation accuracy: 54.95%
# Epoch 4/10
# Validation accuracy: 58.71%
# Epoch 5/10
# Validation accuracy: 60.99%
# Epoch 6/10
# Validation accuracy: 62.40%
# Epoch 7/10
# Validation accuracy: 63.82%
# Epoch 8/10
# Validation accuracy: 63.23%
# Epoch 9/10
# Validation accuracy: 65.79%
# Epoch 10/10
# Validation accuracy: 67.00%
# 32 3 1
# Epoch 1/10
# Validation accuracy: 46.77%
# Epoch 2/10
# Validation accuracy: 53.64%
# Epoch 3/10
# Validation accuracy: 57.55%
# Epoch 4/10
# Validation accuracy: 60.91%
# Epoch 5/10
# Validation accuracy: 63.39%
# Epoch 6/10
# Validation accuracy: 64.71%
# Epoch 7/10
# Validation accuracy: 67.76%
# Epoch 8/10
# Validation accuracy: 68.00%
# Epoch 9/10
# Validation accuracy: 68.47%
# Epoch 10/10
# Validation accuracy: 70.80%
# 64 3 1
# Epoch 1/10
# Validation accuracy: 46.65%
# Epoch 2/10
# Validation accuracy: 55.12%
# Epoch 3/10
# Validation accuracy: 59.95%
# Epoch 4/10
# Validation accuracy: 63.87%
# Epoch 5/10
# Validation accuracy: 66.39%
# Epoch 6/10
# Validation accuracy: 67.38%
# Epoch 7/10
# Validation accuracy: 69.41%
# Epoch 8/10
# Validation accuracy: 70.02%
# Epoch 9/10
# Validation accuracy: 71.21%
# Epoch 10/10
# Validation accuracy: 71.92%
# 128 3 1
# Epoch 1/10
# Validation accuracy: 51.46%
# Epoch 2/10
# Validation accuracy: 58.67%
# Epoch 3/10
# Validation accuracy: 62.35%
# Epoch 4/10
# Validation accuracy: 65.98%
# Epoch 5/10
# Validation accuracy: 67.24%
# Epoch 6/10
# Validation accuracy: 69.23%
# Epoch 7/10
# Validation accuracy: 68.88%
# Epoch 8/10
# Validation accuracy: 71.40%
# Epoch 9/10
# Validation accuracy: 72.80%
# Epoch 10/10
# Validation accuracy: 73.70%
# Task 2 with different kernel sizes
# 16 3 1
# Epoch 1/10
# Validation accuracy: 45.77%
# Epoch 2/10
# Validation accuracy: 52.67%
# Epoch 3/10
# Validation accuracy: 56.32%
# Epoch 4/10
# Validation accuracy: 59.18%
# Epoch 5/10
# Validation accuracy: 61.91%
# Epoch 6/10
# Validation accuracy: 62.90%
# Epoch 7/10
# Validation accuracy: 63.83%
# Epoch 8/10
# Validation accuracy: 65.90%
# Epoch 9/10
# Validation accuracy: 66.85%
# Epoch 10/10
# Validation accuracy: 66.34%
# 16 5 1
# Epoch 1/10
# Validation accuracy: 45.65%
# Epoch 2/10
# Validation accuracy: 52.03%
# Epoch 3/10
# Validation accuracy: 57.98%
# Epoch 4/10
# Validation accuracy: 59.41%
# Epoch 5/10
# Validation accuracy: 63.87%
# Epoch 6/10
# Validation accuracy: 64.51%
# Epoch 7/10
# Validation accuracy: 65.41%
# Epoch 8/10
# Validation accuracy: 65.77%
# Epoch 9/10
# Validation accuracy: 66.79%
# Epoch 10/10
# Validation accuracy: 69.50%
# 16 7 1
# Epoch 1/10
# Validation accuracy: 43.56%
# Epoch 2/10
# Validation accuracy: 49.50%
# Epoch 3/10
# Validation accuracy: 53.81%
# Epoch 4/10
# Validation accuracy: 57.94%
# Epoch 5/10
# Validation accuracy: 59.61%
# Epoch 6/10
# Validation accuracy: 62.04%
# Epoch 7/10
# Validation accuracy: 61.73%
# Epoch 8/10
# Validation accuracy: 62.97%
# Epoch 9/10
# Validation accuracy: 64.65%
# Epoch 10/10
# Validation accuracy: 66.07%
# 16 9 1
# Epoch 1/10
# Validation accuracy: 44.18%
# Epoch 2/10
# Validation accuracy: 48.98%
# Epoch 3/10
# Validation accuracy: 53.61%
# Epoch 4/10
# Validation accuracy: 57.57%
# Epoch 5/10
# Validation accuracy: 57.76%
# Epoch 6/10
# Validation accuracy: 60.04%
# Epoch 7/10
# Validation accuracy: 61.70%
# Epoch 8/10
# Validation accuracy: 61.96%
# Epoch 9/10
# Validation accuracy: 61.39%
# Epoch 10/10
# Validation accuracy: 64.04%
# Task 3 with different padding
# 16 3 0
# Epoch 1/10
# Validation accuracy: 40.60%
# Epoch 2/10
# Validation accuracy: 47.83%
# Epoch 3/10
# Validation accuracy: 52.33%
# Epoch 4/10
# Validation accuracy: 55.26%
# Epoch 5/10
# Validation accuracy: 58.02%
# Epoch 6/10
# Validation accuracy: 60.12%
# Epoch 7/10
# Validation accuracy: 61.48%
# Epoch 8/10
# Validation accuracy: 61.68%
# Epoch 9/10
# Validation accuracy: 63.29%
# Epoch 10/10
# Validation accuracy: 64.03%
# 16 3 1
# Epoch 1/10
# Validation accuracy: 43.07%
# Epoch 2/10
# Validation accuracy: 50.97%
# Epoch 3/10
# Validation accuracy: 55.32%
# Epoch 4/10
# Validation accuracy: 58.70%
# Epoch 5/10
# Validation accuracy: 61.48%
# Epoch 6/10
# Validation accuracy: 63.55%
# Epoch 7/10
# Validation accuracy: 63.50%
# Epoch 8/10
# Validation accuracy: 65.61%
# Epoch 9/10
# Validation accuracy: 65.54%
# Epoch 10/10
# Validation accuracy: 66.97%
# 16 3 2
# Epoch 1/10
# Validation accuracy: 44.89%
# Epoch 2/10
# Validation accuracy: 52.09%
# Epoch 3/10
# Validation accuracy: 55.79%
# Epoch 4/10
# Validation accuracy: 59.72%
# Epoch 5/10
# Validation accuracy: 60.86%
# Epoch 6/10
# Validation accuracy: 62.71%
# Epoch 7/10
# Validation accuracy: 62.95%
# Epoch 8/10
# Validation accuracy: 64.81%
# Epoch 9/10
# Validation accuracy: 65.89%
# Epoch 10/10
# Validation accuracy: 66.98%
# 16 3 3
# Epoch 1/10
# Validation accuracy: 44.15%
# Epoch 2/10
# Validation accuracy: 51.47%
# Epoch 3/10
# Validation accuracy: 54.86%
# Epoch 4/10
# Validation accuracy: 57.13%
# Epoch 5/10
# Validation accuracy: 60.85%
# Epoch 6/10
# Validation accuracy: 62.45%
# Epoch 7/10
# Validation accuracy: 63.42%
# Epoch 8/10
# Validation accuracy: 65.28%
# Epoch 9/10
# Validation accuracy: 65.98%
# Epoch 10/10
# Validation accuracy: 66.41%
